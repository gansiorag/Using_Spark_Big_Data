# %%
from pyspark import SparkConf, SparkContext

# %%
conf = SparkConf().setMaster("local").setAppName("rubik")
sc = SparkContext(conf=conf)
# Out:
# 24/07/24 07:31:52 WARN Utils: Your hostname, al-Dell resolves to a loopback address: 127.0.1.1; using 192.168.106.200 instead (on interface wlp0s20f3)
# 24/07/24 07:31:52 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/07/24 07:31:52 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
array_kub = [[111111111],[222222222],[333333333],[444444444],[555555555],[666666666]]

# %%
rdd = sc.parallelize(array_kub)
rdd.count()
# Out:
# 6

# %%
rdd.getNumPartitions()
# Out:
# 1
